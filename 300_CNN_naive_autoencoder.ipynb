# %% [markdown]
# # Convolutional Autoencoder with MNIST
#
# - fashion_mnist dataset 을 이용한 deep autoencoder 생성

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, UpSampling2D, MaxPooling2D
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
(X_train, _), (X_test, _) = fashion_mnist.load_data()
X_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# (60000, 28, 28)

# %%
X_train = X_train / 255.
X_test = X_test / 255.

X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# # Convolutional autoencoder
#
# <img src="https://drive.google.com/uc?export=view&id=15zh7bst9KKvciRdCvMAH7kXt3nNkABzO" width="75%" height="75%"/>

# %%
# 입력 레이어를 정의합니다. 28x28 픽셀, 1채널(흑백)의 이미지를 사용합니다.
input = Input(shape=(28, 28, 1))

# Encoder
conv_1 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(input)
maxpool_1 = MaxPooling2D(pool_size=(2,2))(conv_1)

conv_2 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(maxpool_1)
maxpool_2 = MaxPooling2D(pool_size=(2,2))(conv_2)

# 병목 레이어
bottle_neck = Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(maxpool_2)

# Decoder
conv_3 = Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(bottle_neck)
upsample_3 = UpSampling2D(size=(2,2))(conv_3)

conv_4 = Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(upsample_3)
upsample_4 = UpSampling2D(size=(2,2))(conv_4)

# 이 레이어의 출력은 원본 이미지와 같은 크기의 복원된 이미지
conv_5 = Conv2D(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same')(upsample_4)

# %%
# autoencoder model
autoencoder = Model(inputs=input, outputs=conv_5)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         295040
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 128)       0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        73792
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 1)         577
#
# =================================================================
# Total params: 739073 (2.82 MB)
# Trainable params: 739073 (2.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# encoder model for visualization
encoder_viz = Conv2D(filters=1, kernel_size=(3,3), activation='relu', padding='same')(bottle_neck)
encoder_model = Model(inputs=input, outputs=encoder_viz)

# %%
encoder_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 1)           2305
#
# =================================================================
# Total params: 371969 (1.42 MB)
# Trainable params: 371969 (1.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(autoencoder, show_shapes=True)

# %%
history = autoencoder.fit(X_train, X_train, epochs=50, shuffle=True,
                          batch_size=256, validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 16s 32ms/step - loss: 0.3035 - val_loss: 0.2744
# Epoch 2/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2679 - val_loss: 0.2658
# Epoch 3/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2621 - val_loss: 0.2622
# Epoch 4/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2585 - val_loss: 0.2590
# Epoch 5/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2562 - val_loss: 0.2570
# Epoch 6/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2543 - val_loss: 0.2562
# Epoch 7/50
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2530 - val_loss: 0.2544
# Epoch 8/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2519 - val_loss: 0.2534
# Epoch 9/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2512 - val_loss: 0.2527
# Epoch 10/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2506 - val_loss: 0.2531
# Epoch 11/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2501 - val_loss: 0.2524
# Epoch 12/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2497 - val_loss: 0.2515
# Epoch 13/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2493 - val_loss: 0.2510
# Epoch 14/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2491 - val_loss: 0.2507
# Epoch 15/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2487 - val_loss: 0.2506
# Epoch 16/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2486 - val_loss: 0.2504
# Epoch 17/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2483 - val_loss: 0.2500
# Epoch 18/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2482 - val_loss: 0.2501
# Epoch 19/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2479 - val_loss: 0.2500
# Epoch 20/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2477 - val_loss: 0.2496
# Epoch 21/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2475 - val_loss: 0.2494
# Epoch 22/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2474 - val_loss: 0.2493
# Epoch 23/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2472 - val_loss: 0.2490
# Epoch 24/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2471 - val_loss: 0.2490
# Epoch 25/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2469 - val_loss: 0.2489
# Epoch 26/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2468 - val_loss: 0.2487
# Epoch 27/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2467 - val_loss: 0.2485
# Epoch 28/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2466 - val_loss: 0.2488
# Epoch 29/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2465 - val_loss: 0.2485
# Epoch 30/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2463 - val_loss: 0.2488
# Epoch 31/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2462 - val_loss: 0.2490
# Epoch 32/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2461 - val_loss: 0.2481
# Epoch 33/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2460 - val_loss: 0.2482
# Epoch 34/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2459 - val_loss: 0.2481
# Epoch 35/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2458 - val_loss: 0.2488
# Epoch 36/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2458 - val_loss: 0.2480
# Epoch 37/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2457 - val_loss: 0.2477
# Epoch 38/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2457 - val_loss: 0.2477
# Epoch 39/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2455 - val_loss: 0.2476
# Epoch 40/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2455 - val_loss: 0.2475
# Epoch 41/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2454 - val_loss: 0.2477
# Epoch 42/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2453 - val_loss: 0.2477
# Epoch 43/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2453 - val_loss: 0.2474
# Epoch 44/50
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2452 - val_loss: 0.2477
# Epoch 45/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2452 - val_loss: 0.2472
# Epoch 46/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2451 - val_loss: 0.2473
# Epoch 47/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2451 - val_loss: 0.2472
# Epoch 48/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2450 - val_loss: 0.2471
# Epoch 49/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2450 - val_loss: 0.2475
# Epoch 50/50
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2449 - val_loss: 0.2472

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation_loss')
plt.legend()

# %%
fig, ax = plt.subplots(3, 10, figsize=(20, 4))

for i in range(10):
    ax[0, i].imshow(X_test[i].reshape(28, 28), cmap='gray')
    img = np.expand_dims(X_test[i], axis=0)
    ax[1, i].imshow(encoder_model.predict(img).reshape(7, 7), cmap='gray')
    ax[2, i].imshow(autoencoder.predict(img).reshape(28, 28), cmap='gray')
# Out:
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
