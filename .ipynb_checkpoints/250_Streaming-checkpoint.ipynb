# %% [markdown]
# # 스트리밍 API 응답
# 기본적으로 OpenAI API에 요청을 보내면 모델의 전체 출력을 생성한 후 단일 HTTP 응답으로 다시 전송합니다. 긴 출력을 생성할 경우 응답을 기다리는 데 시간이 걸릴 수 있습니다.
# 스트리밍 응답을 사용하면 전체 응답을 생성하는 동안 모델 출력의 시작 부분을 인쇄하거나 처리할 수 있습니다.
#
# 응답 스트리밍을 시작하려면 stream=True응답 엔드포인트에 대한 요청을 설정합니다.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-4.1-nano"

# %%
stream = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": "성경의 창세기 시작 부분을 1000 글자내에서 알려줘.",
        },
    ],
    stream=True,
)

for chunk in stream:
    if chunk.type == 'response.output_text.delta':
        print(chunk.delta, end="")
# Out:
# 물론입니다. 성경 창세기(창세기 1장)의 시작 부분을 약 1000글자 이내로 요약해 드리겠습니다.
#
# ---
#
# 태초에 하나님이 천지를 창조하시니라. 땅이 혼돈하고 공허하며 흑암이 깊음 위에 있고 하나님의 영이 수면 위에 운행하시니라. 하나님이 말씀하시되 "빛이 있으라" 하시니 빛이 생기고, 하나님이 그 빛을 보시고 좋다고 하사 빛과 어두움을 나누사, 빛은 낮으로, 어두움은 밤으로 정하셨다. 저녁이 되고 아침이 되니 첫째 날이라. 하나님이 하늘을 만드사 물 가운데에 궁창을 만드셔서 물과 물을 나누셨다. 궁창 위의 물과 아래의 물을 나누셨다. 하나님이 궁창을 천계라 부르시고, 저녁이 되고 아침이 되니 두째 날이라. 또 하나님이 땅이 드러나게 하시고, 땅이 풀과 각종 씨 맺는 채소와 열매 맺는 나무를 내게 하셨다. 저녁이 되고 아침이 되니 셋째 날이라. 하나님이 빛들을 만드사 낮과 밤을 나누게 하시고, 계절과, 날과, 해와 달을 정하셔서 땅에 시간을 이루게 하셨다. (이후 생물과 인간 창조 등 이야기 계속됨)
#
# ---
#
# 이 요약은 성경 창세기 1장 전체의 핵심 내용을 간결하게 담았으며, 원문 전체는 더 긴 내용을 포함하고 있습니다. 추가로 궁금하신 점이 있으시면 말씀해 주세요!
