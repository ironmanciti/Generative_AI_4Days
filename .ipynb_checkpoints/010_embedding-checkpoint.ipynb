# %% [markdown]
# #  문장 내의 단어들을 임베딩
# - keras.layers.Embedding 레이어 사용

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Embedding

# 샘플 데이터: 간단한 문장들의 모음
sentences = [
    "I love machine learning",
    "I love coding in Python",
    "Deep learning is fun"
]

# %%
# 각 문장을 단어로 분할하고, 각 단어에 대한 고유한 인덱스를 생성
word_index = {}

for sentence in sentences:
    for word in sentence.split():
        if word not in word_index:
            word_index[word] = len(word_index) + 1
            
word_index
# Out:
# {'I': 1,
#  'love': 2,
#  'machine': 3,
#  'learning': 4,
#  'coding': 5,
#  'in': 6,
#  'Python': 7,
#  'Deep': 8,
#  'is': 9,
#  'fun': 10}

# %%
# 문장들을 단어 인덱스의 시퀀스로 변환
sequences = [[word_index[word] for word in sentence.split()] for sentence in sentences]
sequences
# Out:
# [[1, 2, 3, 4], [1, 2, 5, 6, 7], [8, 4, 9, 10]]

# %%
# 문장들 중 가장 긴 것의 길이를 구함
max_length = max([len(seq) for seq in sequences])

# 모든 문장을 가장 긴 문장의 길이로 패딩
padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences, maxlen=max_length, padding='post')
padded_sequences
# Out:
# array([[ 1,  2,  3,  4,  0],
#        [ 1,  2,  5,  6,  7],
#        [ 8,  4,  9, 10,  0]])

# %%
# Embedding 레이어 생성
embedding_dim = 10
embedding_layer = Embedding(input_dim=len(word_index) + 1, output_dim=embedding_dim, input_length=max_length)

# 패딩된 시퀀스를 Embedding 레이어에 통과시켜 임베딩된 결과를 얻음
embedded_sequences = embedding_layer(padded_sequences)

print(embedded_sequences.shape)
print(embedded_sequences)
# Out:
# (3, 5, 10)
# tf.Tensor(
# [[[ 0.03914941 -0.0249617  -0.02278559 -0.01709235 -0.04161712
#     0.01809633  0.01753887  0.00227978 -0.03607588 -0.00460954]
#   [ 0.04516144 -0.03648543  0.00325447  0.016378   -0.03179113
#     0.03239692 -0.02780606  0.02489214 -0.04579481  0.02020638]
#   [-0.0241824  -0.03325494  0.0433637  -0.00352098  0.00534834
#     0.01556268  0.0019931  -0.04698711  0.02165775  0.03126117]
#   [-0.04765958  0.00948986  0.00633069 -0.03085752  0.00146889
#     0.01110678  0.03008712  0.00607376 -0.04467111 -0.00210092]
#   [-0.01938688 -0.00961684  0.03184977 -0.04238187  0.01999063
#     0.02582332  0.0405792   0.03202636 -0.00901568 -0.03144144]]
#
#  [[ 0.03914941 -0.0249617  -0.02278559 -0.01709235 -0.04161712
#     0.01809633  0.01753887  0.00227978 -0.03607588 -0.00460954]
#   [ 0.04516144 -0.03648543  0.00325447  0.016378   -0.03179113
#     0.03239692 -0.02780606  0.02489214 -0.04579481  0.02020638]
#   [-0.02227796 -0.04753477  0.00562694 -0.0074909  -0.04035969
#     0.01740194 -0.04436871  0.00575035 -0.03694795 -0.01999047]
#   [ 0.0027983  -0.04383855  0.04768956 -0.03038681  0.04025895
#    -0.04859766  0.03252398 -0.0024449  -0.03642883  0.01406978]
#   [ 0.04184765 -0.0141181  -0.03580995  0.00936091  0.02190976
#     0.0496589  -0.02660079  0.02950813  0.03924966 -0.02020971]]
#
#  [[ 0.00037747 -0.04397317  0.00100083  0.01847304  0.03805408
#     0.04082412 -0.00201745 -0.04051956 -0.03107107 -0.02352949]
#   [-0.04765958  0.00948986  0.00633069 -0.03085752  0.00146889
#     0.01110678  0.03008712  0.00607376 -0.04467111 -0.00210092]
#   [-0.03863044  0.04164248 -0.0159809   0.02913982  0.00913863
#     0.02768529  0.02506531 -0.01153867  0.01968985  0.01700537]
#   [ 0.02624872  0.01796875  0.01346359  0.02156537 -0.01121174
#    -0.03588436 -0.02467197 -0.0134354  -0.0477041   0.01991601]
#   [-0.01938688 -0.00961684  0.03184977 -0.04238187  0.01999063
#     0.02582332  0.0405792   0.03202636 -0.00901568 -0.03144144]]], shape=(3, 5, 10), dtype=float32)

# %%
# Embedding 레이어의 가중치 (단어 임베딩 행렬) 출력
embeddings = embedding_layer.get_weights()[0]
print("Embedding 레이어의 Shape :", embeddings.shape)
print("Embedding 레이어의 가중치(Word Embeddings):\n", embeddings)
print()

# 예: 'love'라는 단어의 임베딩 벡터를 출력
print("\n단어 'love'의 임베딩 벡터 표현:\n", embeddings[word_index['love']])
# Out:
# Embedding 레이어의 Shape : (11, 10)
# Embedding 레이어의 가중치(Word Embeddings):
#  [[-0.01938688 -0.00961684  0.03184977 -0.04238187  0.01999063  0.02582332
#    0.0405792   0.03202636 -0.00901568 -0.03144144]
#  [ 0.03914941 -0.0249617  -0.02278559 -0.01709235 -0.04161712  0.01809633
#    0.01753887  0.00227978 -0.03607588 -0.00460954]
#  [ 0.04516144 -0.03648543  0.00325447  0.016378   -0.03179113  0.03239692
#   -0.02780606  0.02489214 -0.04579481  0.02020638]
#  [-0.0241824  -0.03325494  0.0433637  -0.00352098  0.00534834  0.01556268
#    0.0019931  -0.04698711  0.02165775  0.03126117]
#  [-0.04765958  0.00948986  0.00633069 -0.03085752  0.00146889  0.01110678
#    0.03008712  0.00607376 -0.04467111 -0.00210092]
#  [-0.02227796 -0.04753477  0.00562694 -0.0074909  -0.04035969  0.01740194
#   -0.04436871  0.00575035 -0.03694795 -0.01999047]
#  [ 0.0027983  -0.04383855  0.04768956 -0.03038681  0.04025895 -0.04859766
#    0.03252398 -0.0024449  -0.03642883  0.01406978]
#  [ 0.04184765 -0.0141181  -0.03580995  0.00936091  0.02190976  0.0496589
#   -0.02660079  0.02950813  0.03924966 -0.02020971]
#  [ 0.00037747 -0.04397317  0.00100083  0.01847304  0.03805408  0.04082412
#   -0.00201745 -0.04051956 -0.03107107 -0.02352949]
#  [-0.03863044  0.04164248 -0.0159809   0.02913982  0.00913863  0.02768529
#    0.02506531 -0.01153867  0.01968985  0.01700537]
#  [ 0.02624872  0.01796875  0.01346359  0.02156537 -0.01121174 -0.03588436
#   -0.02467197 -0.0134354  -0.0477041   0.01991601]]
#
#
# 단어 'love'의 임베딩 벡터 표현:
#  [ 0.04516144 -0.03648543  0.00325447  0.016378   -0.03179113  0.03239692
#  -0.02780606  0.02489214 -0.04579481  0.02020638]

# %% [markdown]
# 0은 보통 패딩을 나타내는 인덱스로 사용됩니다. 결과적으로, Embedding 레이어의 가중치 행렬의 크기는 (고유한 단어 수 + 1, 임베딩 벡터의 차원수)가 되므로, (11, 8)이 됩니다.

# %%
import pandas as pd

# 임베딩 레이어의 가중치를 numpy array로 변환
embeddings_array = np.array(embeddings)

# 단어 인덱스를 뒤집어서, 인덱스로부터 단어를 얻을 수 있는 딕셔너리를 생성
index_word = {i: word for word, i in word_index.items()}

# Embedding 행렬을 Pandas DataFrame으로 변환
embedding_df = pd.DataFrame(embeddings_array)
embedding_df.index = [index_word.get(i, 'PAD') for i in range(len(embeddings_array))]
embedding_df
# Out:
#                  0         1         2         3         4         5  \
# PAD      -0.019387 -0.009617  0.031850 -0.042382  0.019991  0.025823
# I         0.039149 -0.024962 -0.022786 -0.017092 -0.041617  0.018096
# love      0.045161 -0.036485  0.003254  0.016378 -0.031791  0.032397
# machine  -0.024182 -0.033255  0.043364 -0.003521  0.005348  0.015563
# learning -0.047660  0.009490  0.006331 -0.030858  0.001469  0.011107
# coding   -0.022278 -0.047535  0.005627 -0.007491 -0.040360  0.017402
# in        0.002798 -0.043839  0.047690 -0.030387  0.040259 -0.048598
# Python    0.041848 -0.014118 -0.035810  0.009361  0.021910  0.049659
# Deep      0.000377 -0.043973  0.001001  0.018473  0.038054  0.040824
# is       -0.038630  0.041642 -0.015981  0.029140  0.009139  0.027685
# fun       0.026249  0.017969  0.013464  0.021565 -0.011212 -0.035884
#
#                  6         7         8         9
# PAD       0.040579  0.032026 -0.009016 -0.031441
# I         0.017539  0.002280 -0.036076 -0.004610
# love     -0.027806  0.024892 -0.045795  0.020206
# machine   0.001993 -0.046987  0.021658  0.031261
# learning  0.030087  0.006074 -0.044671 -0.002101
# coding   -0.044369  0.005750 -0.036948 -0.019990
# in        0.032524 -0.002445 -0.036429  0.014070
# Python   -0.026601  0.029508  0.039250 -0.020210
# Deep     -0.002017 -0.040520 -0.031071 -0.023529
# is        0.025065 -0.011539  0.019690  0.017005
# fun      -0.024672 -0.013435 -0.047704  0.019916
