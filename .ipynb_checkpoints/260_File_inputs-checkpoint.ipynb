# %% [markdown]
# # 파일 입력
# 비전 기능을 갖춘 OpenAI 모델은 PDF 파일을 입력으로 사용할 수도 있습니다.
#
# 모델이 PDF 콘텐츠를 이해할 수 있도록 각 페이지의 추출된 텍스트와 이미지를 모델의 컨텍스트에 추가합니다. 모델은 텍스트와 이미지를 모두 사용하여 응답을 생성할 수 있습니다. 이는 예를 들어 다이어그램에 텍스트에 없는 주요 정보가 포함된 경우 유용합니다.
#
# 먼저 Files API를 사용하여 PDF를 업로드한 다음, 모델에 대한 API 요청에서 해당 파일 ID를 참조합니다.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-4.1-nano"

# %%
from openai import OpenAI
client = OpenAI()

file = client.files.create(
    file=open("data/삼성중공업-기업리포트.pdf", "rb"),
    purpose="user_data"
)

response = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_file",
                    "file_id": file.id,
                },
                {
                    "type": "input_text",
                    "text": "파일 내에 있는 첫번째 바차트를 설명해줘.",
                },
            ]
        }
    ]
)

print(response.output_text)
# Out:
# 첫 번째 바 차트는 전세계 LNG선 플레이어의 수주잔고와 시장 점유율(M/S, Market Share)을 보여줍니다. 차트에는 두 가지 데이터가 표시되어 있는데, 왼쪽 축에는 수주잔고의 척도(척수, 배) 가 나타나고, 오른쪽 축에는 각 선사의 시장 점유율(%)이 표시되어 있습니다.
#
# 차트에서 알 수 있는 내용은 다음과 같습니다:
# - 글로벌 LNG선 시장의 주요 플레이어들이 각각의 수주잔고와 시장 점유율을 보유하고 있으며, 특히 한국 기업들이 높은 수주잔고와 점유율을 차지하고 있음.
# - 왼쪽 바는 각 선사의 수주잔고를 나타내며, 수치가 높을수록 해당 기업이 보유한 LNG선 수가 많다는 의미.
# - 오른쪽 바는 각 기업의 시장 점유율을 보여주며, 이는 전체 LNG선 시장 내에서 각 기업이 차지하는 비중을 의미.
#
# 이 차트는 글로벌 LNG선 시장에서 삼성중공업 등 한국 조선사의 경쟁 위치와 시장 점유율을 시각적으로 보여주며, 시장의 경쟁 구도와 각 기업의 수주 성과를 파악할 수 있도록 도와줍니다.

# %% [markdown]
# ### Base64로 인코딩된 파일
# PDF 파일 입력도 Base64로 인코딩된 입력으로 보낼 수 있습니다.

# %%
import base64

with open("data/삼성중공업-기업리포트.pdf", "rb") as f:
    data = f.read()

base64_string = base64.b64encode(data).decode("utf-8")

response = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_file",
                    "filename": "삼성중공업-기업리포트.pdf",
                    "file_data": f"data:application/pdf;base64,{base64_string}",
                },
                {
                    "type": "input_text",
                    "text": "파일 내에 있는 첫번째 바차트를 설명해줘.",
                },
            ],
        },
    ]
)

print(response.output_text)
# Out:
# 첫 번째 차트는 "전세계 LNG선 플레이어의 수주잔고와 M/S"를 보여줍니다. 차트에는 여러 글로벌 선박 제조사와 조선소들이 포함되어 있으며, 좌측 축은 수주잔고(척수), 우측 축은 시장 점유율(%)를 나타내고 있습니다.
#
# 차트 상단에는 각 조선사의 이름이 표시되어 있으며, 각자 차트 내에서 수주잔고와 시장 점유율이 나타나 있습니다. 예를 들어, 중국의 Hudong Zhonghua, Dalian Shipbuilding, Zvezda SB, CMHI (Jiangsu) 등과 한국의 삼성중공업, 현대중공업 등이 포함되어 있습니다.
#
# 이 차트는 전 세계 LNG선 시장에서 각 기업이 얼마나 많은 선박을 수주했으며, 시장 내 점유율이 어떤지 보여줍니다. 전체적으로 중국 선박사들이 매우 높은 수주잔고와 시장 점유율을 차지하고 있음을 알 수 있으며, 삼성중공업은 상대적으로 작은 규모를 보이고 있습니다.
