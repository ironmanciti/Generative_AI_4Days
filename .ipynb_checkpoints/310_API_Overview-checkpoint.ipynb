# %% [markdown]
# # API 사용 Overview

# %%
# !pip install -q openai
# !pip install -q python-dotenv

# %%
import os
import openai
import sys
sys.path.append('./')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ### OpenAI 사용 가능 모델 목록

# %%
counter = 0
for model in client.models.list():
    print(model.id)
    counter += 1
    if counter == 5:
        break
# Out:
# dall-e-3
# whisper-1
# tts-1
# dall-e-2
# tts-1-hd-1106

# %% [markdown]
# ### 채팅 API
#
# Chat Completions API : https://platform.openai.com/docs/guides/text-generation/chat-completions-api

# %% [markdown]
# ## role of the messages author
#
# OpenAI API에서 각 메시지의 저자(`author`) 역할은 다음과 같은 의미를 가집니다:
#
# 1. **system**: 시스템 관련 메시지나 지침. 예를 들면, 어시스턴트에게 특정 작업을 수행하는 방법에 대한 지침을 제공하는 경우에 사용됩니다. 이러한 지침은 어시스턴트의 응답을 안내하거나 제한할 수 있습니다.
#
# 2. **user**: 사용자가 입력한 메시지. 대체로 사용자의 질문, 요청, 지침 등을 나타냅니다.
#
# 3. **assistant**: 어시스턴트(즉, 모델)가 반환하는 응답 또는 메시지. 사용자의 질문에 대한 답변, 제안, 설명 등을 포함할 수 있습니다.

# %%
# Q & A
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "2022년 FIFA 월드컵 우승한 나라가 어디인가요?"},
    {"role": "assistant", "content": "2022년 FIFA 월드컵 우승국은 아르헨티나입니다."},
    {"role": "user", "content": "어디에서 개최되었나요?"}
  ]
)

response
# Out:
# ChatCompletion(id='chatcmpl-9loiqWhhqNUmjhXHVTxhtPCNY6RoY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='2022년 FIFA 월드컵은 카타르에서 개최되었습니다.', role='assistant', function_call=None, tool_calls=None))], created=1721183420, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=26, prompt_tokens=93, total_tokens=119))

# %%
print(response.choices[0].message.content)
# Out:
# 2022년 FIFA 월드컵은 카타르에서 개최되었습니다.

# %%
# 시 작성
completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, 복잡한 프로그래밍 개념을 창의적인 방식으로 설명하는 데 능숙합니다."},
    {"role": "user", "content": "프로그래밍의 재귀 개념을 설명하는 시를 작성하세요."}
  ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='무한한 반복을 꿈꾸는 마음이여,\n재귀의 세계로 들어가 보라.\n자신을 부르는 소리가 울려 퍼지며,\n연쇄적으로 이어지는 함수의 바다.\n\n기절할 듯한 미로 속을 거닐다 보면,\n작은 조각들이 모여 큰 그림을 이룬다.\n재귀의 마법은 반복의 굴레를 벗어나게 하며,\n복잡함을 단순함으로 바꾸어 준다.\n\n마치 천재의 작품을 감상하는 듯,\n재귀는 우리에게 아름다운 세계를 여는 문이다.\n한 발짝 내디딜 때마다 새로운 이야기가 펼쳐지며,\n프로그래머의 상상력을 자극하는 무한한 가능성을 보여준다.\n\n그러나 주의하라, 재귀의 미로에 갇히기 쉽다.\n기반 없이 끝없는 재귀에 빠져들면,\n스택 오버플로우의 위험에 빠질지도 모른다.\n\n그래도 두렵지 말아라, 재귀는 우리의 친구이니,\n적절히 활용하면 우리의 코드를 더 아름답게 만들어 줄 것이니라.', role='assistant', function_call=None, tool_calls=None)

# %%
print(completion.choices[0].message.content)
# Out:
# 무한한 반복을 꿈꾸는 마음이여,
# 재귀의 세계로 들어가 보라.
# 자신을 부르는 소리가 울려 퍼지며,
# 연쇄적으로 이어지는 함수의 바다.
#
# 기절할 듯한 미로 속을 거닐다 보면,
# 작은 조각들이 모여 큰 그림을 이룬다.
# 재귀의 마법은 반복의 굴레를 벗어나게 하며,
# 복잡함을 단순함으로 바꾸어 준다.
#
# 마치 천재의 작품을 감상하는 듯,
# 재귀는 우리에게 아름다운 세계를 여는 문이다.
# 한 발짝 내디딜 때마다 새로운 이야기가 펼쳐지며,
# 프로그래머의 상상력을 자극하는 무한한 가능성을 보여준다.
#
# 그러나 주의하라, 재귀의 미로에 갇히기 쉽다.
# 기반 없이 끝없는 재귀에 빠져들면,
# 스택 오버플로우의 위험에 빠질지도 모른다.
#
# 그래도 두렵지 말아라, 재귀는 우리의 친구이니,
# 적절히 활용하면 우리의 코드를 더 아름답게 만들어 줄 것이니라.

# %%
# 블로그 생성
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "당신은 경험 많은 카피라이터입니다."},
    {"role": "user", "content": "스타크래프트에 대해 블로그를 생성해줘. "}
  ],
  max_tokens=700,
  temperature=1
)

print(response.choices[0].message.content)
# Out:
# 물론이죠! 스타크래프트는 매우 인기 있는 전략 시뮬레이션 게임으로, 특히 전략적인 요소와 뛰어난 마이크로와 마크로 관련 도전을 즐기는 플레이어들에게 사랑받고 있습니다.
#
# 스타크래프트는 블리자드 엔터테인먼트가 개발하고 출시한 게임으로, 세 개의 종족인 프로토스, 테란, 저그 각각 고유한 유닛과 전략을 가지고 있습니다. 플레이어는 자원을 수집하고 유닛을 생산하여 상대방을 공격하거나 방어하며 승리를 거두는 것이 목표입니다.
#
# 스타크래프트는 고도의 전략과 팀워크가 요구되는 게임으로 스타크래프트 프로게이머들은 전문적인 훈련과 뛰어난 실력을 발휘하여 세계 대회에서 경쟁합니다. 또한 스타크래프트는 많은 인기 대회와 이벤트가 열리며 게이머들에게 큰 관심을 받고 있습니다.
#
# 이 블로그에서는 스타크래프트의 최신 소식, 전략, 팁, 대회 정보 등 다양한 내용을 다룰 것이며, 모든 스타크래프트 팬들에게 유익한 정보를 제공할 예정입니다. 부족한 내용이나 궁금한 사항이 있으시면 언제든지 댓글을 남겨주세요! 함께 즐겁고 흥미진진한 스타크래프트 세계를 탐험해보죠.

# %%
# 형식 지정
custom_content = """
스타크래프트에 대해 블로그를 생성해줘. 형식은 다음과 같이 작성해줘.

주제: 스타크래프트
주요 내용:
"""

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "당신은 경험 많은 카피라이터입니다."},
    {"role": "user", "content": custom_content}
  ],
  max_tokens=700,
  temperature=1
)

print(response.choices[0].message.content)
# Out:
# 주제: 스타크래프트
#
# 주요 내용:
# 1. 스타크래프트란?
# - 스타크래프트는 블리자드 엔터테인먼트가 개발한 전략 시뮬레이션 게임이다. 1998년에 첫 출시된 이후로 전 세계적으로 인기를 끌고 있는 게임으로, 실시간 전략 게임의 대표주자로 꼽힌다.
#
# 2. 스타크래프트의 종족
# - 스타크래프트에는 세 가지 종족이 존재한다. 프로토스, 테란, 저그 각각이 고유한 특성과 전략을 갖고 있어, 게이머들은 자신이 선호하는 종족을 선택할 수 있다.
#
# 3. 스타크래프트 리그
# - 스타크래프트 커뮤니티에는 다양한 리그와 대회들이 존재한다. 프로게이머들이 참가하는 프로게이머 리그부터 일반 유저들이 참가하는 아마추어 리그까지 다양한 토너먼트가 열린다.
#
# 4. 스타크래프트의 전략
# - 스타크래프트는 전략 게임으로 플레이어들은 군대를 이끌며 상대방 기지를 공격하고 방어해야 한다. 맵의 구조, 유닛의 조합, 자원의 수급 등이 승부의 요소가 된다.
#
# 5. 스타크래프트의 영향
# - 스타크래프트는 전 세계적으로 영향력이 큰 게임으로 손꼽힌다. 게이머들뿐만 아니라 전략 시뮬레이션 게임 산업 전체에도 큰 영향을 끼쳤으며, 이를 기반으로 한 다양한 모드와 게임이 출시되었다.
#
# 이렇게 스타크래프트에 대한 다양한 정보를 담아 블로그를 운영하면 스타크래프트 팬들뿐만 아니라 게임 산업에 관심 있는 사람들에게 유익한 정보를 제공할 수 있을 것이다.

# %% [markdown]
# ### Embedding API

# %%
response = client.embeddings.create(
  model="text-embedding-ada-002",
  input="The food was delicious and the waiter..."
)

print(response)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[0.0022974968887865543, -0.00929788127541542, 0.01573975756764412, -0.007679478731006384, -0.004737793933600187, 0.014876609668135643, -0.0098563889041543, -0.03823237866163254, -0.006930570583790541, -0.028610818088054657, 0.02520899847149849, 0.01813880167901516, -0.0036271256394684315, -0.02553902566432953, 0.0005204274784773588, -0.01637442596256733, 0.028280790895223618, 0.005407368298619986, 0.00971041526645422, -0.016399811953306198, -0.015397037379443645, 0.004277660045772791, 0.0069876909255981445, -0.0072859846986830235, -0.003874646034091711, 0.018544988706707954, 0.008752066642045975, -0.02265763469040394, 0.011493830941617489, 0.02390158362686634, 0.015638211742043495, -0.003519232152029872, -0.034932106733322144, -0.004191979765892029, -0.026122920215129852, -0.02151523344218731, -0.005715182051062584, 0.011754045262932777, 0.008453773334622383, 0.004080913029611111, 0.019179657101631165, -0.014419648796319962, 0.008936120197176933, 0.006391103379428387, -0.045670684427022934, 0.017884934321045876, -0.005610461812466383, -0.0007219344261102378, -0.022111820057034492, -0.003953979350626469, 0.02100749872624874, -0.01763106696307659, -0.011696924455463886, -0.02260686084628105, 0.01633634604513645, 0.01717410609126091, -0.008466466329991817, 0.0015922224847599864, 0.025094758719205856, -0.024967825040221214, 0.007806411944329739, 0.005794515833258629, -0.022187981754541397, 0.0029162978753447533, -0.006095982622355223, -0.025564413517713547, -0.008104706183075905, 0.0010178482625633478, 0.0001982344692805782, 0.004642593674361706, 0.020740939304232597, 0.013467647135257721, 0.004626727197319269, -0.016006318852305412, 0.016615599393844604, -0.008948814123868942, -0.007616011891514063, 0.013619967736303806, -0.006974997464567423, 0.005267741624265909, 0.00988177489489317, -0.04592455178499222, 0.003046404803171754, 0.024003131315112114, 0.023013049736618996, 0.00698134396225214, -0.0235715564340353, 0.00993889570236206, -0.0065370770171284676, -0.03333274647593498, -0.0026909909211099148, 0.01992856338620186, 0.001759616076014936, 0.0010908349649980664, -0.022683022543787956, 0.005007527768611908, 0.01540973037481308, 0.031530287116765976, -0.005467661656439304, -0.015980930998921394, -0.005147154442965984, 0.01989048346877098, -0.00938673410564661, -0.006213396321982145, -0.031174875795841217, -0.009405774995684624, -0.015270103700459003, -0.02886468544602394, 0.02102019265294075, -0.01830381527543068, -0.002921057865023613, 0.012693352997303009, 0.0051027280278503895, -0.04958023503422737, -0.0430050790309906, -0.0004129306471440941, 0.021578699350357056, -0.016894852742552757, 0.006543423514813185, -0.04143110290169716, 0.0009662815136834979, 0.03351045027375221, 0.012890099547803402, -0.010510096326470375, -0.0005807208945043385, 0.018354589119553566, 9.286972635891289e-05, -0.013099540024995804, 0.011982524767518044, 0.005813555791974068, 0.007019424345344305, 0.008637826889753342, 0.01845613494515419, -0.000855214660987258, -0.019141577184200287, 0.021896034479141235, -0.029753219336271286, -0.004322086460888386, 0.0015160623006522655, -0.00520744826644659, 0.014952769502997398, 0.021388299763202667, -0.018836935982108116, 0.011055910028517246, -0.007463691756129265, 0.02263224869966507, 0.019141577184200287, 0.014952769502997398, -0.0036810722667723894, 0.006286383140832186, 0.02567865327000618, -0.02777305617928505, 0.036683790385723114, -0.004458540119230747, 0.013911915011703968, 0.00801585242152214, -0.005673928651958704, 0.010281615890562534, -0.005765955429524183, -0.008726679719984531, 0.010649723000824451, 2.0787843823200092e-05, 0.032164957374334335, -0.023838117718696594, -0.002641804050654173, 0.030387887731194496, 0.029626285657286644, 0.016602905467152596, 0.0021784966811537743, 0.0010519616771489382, -0.011652498506009579, 0.018519602715969086, -0.007552545052021742, 0.007419264875352383, -0.0011090816697105765, 0.004433153662830591, 0.0099896686 ...

# %%
import numpy as np
embedding = np.array(response.data[0].embedding)
embedding.shape
# Out:
# (1536,)

# %% [markdown]
# - 여러개의 문장의 유사도 비교

# %%
from scipy.spatial.distance import cosine

# 텍스트 리스트
texts = [
     "음식이 맛있었고 웨이터가 매우 친절했습니다.",
     "분위기는 좋았지만 음식은 그냥 그래요.",
     "저는 음식이 마음에 들었고 웨이터는 매우 세심했습니다."
]

# 임베딩 생성 함수
def get_embedding(text):
    response = client.embeddings.create(
          model="text-embedding-ada-002",
          input=text
        )
    return np.array(response.data[0].embedding)

# 임베딩 생성
embeddings = [get_embedding(text) for text in texts]

# 코사인 유사도 계산 함수
def cosine_similarity(vec1, vec2):
    return 1 - cosine(vec1, vec2)

# 코사인 유사도 계산 및 출력
simi_0_1 = cosine_similarity(embeddings[0], embeddings[1])
simi_0_2 = cosine_similarity(embeddings[0], embeddings[2])
simi_1_2 = cosine_similarity(embeddings[1], embeddings[2])

for i, text in enumerate(texts):
    print(f"test {i} : {text}")

print()
print(f"Similarity between text 0 and text 1: {simi_0_1}")
print(f"Similarity between text 0 and text 2: {simi_0_2}")
print(f"Similarity between text 1 and text 2: {simi_1_2}")
print()
# Out:
# test 0 : 음식이 맛있었고 웨이터가 매우 친절했습니다.
# test 1 : 분위기는 좋았지만 음식은 그냥 그래요.
# test 2 : 저는 음식이 마음에 들었고 웨이터는 매우 세심했습니다.
#
# Similarity between text 0 and text 1: 0.8580361503035346
# Similarity between text 0 and text 2: 0.9475007770789197
# Similarity between text 1 and text 2: 0.8564659324503545

# %%
# 각 유사도를 리스트로 정리
similarities = [
    (simi_0_1, (0, 1)),
    (simi_0_2, (0, 2)),
    (simi_1_2, (1, 2))
]

# 유사도를 내림차순으로 정렬하고 가장 유사한 쌍을 출력
for simi, pair in sorted(similarities, reverse=True):
    print(f"text {pair[0]} 와 text {pair[1]} 이 가장 유사합니다.")
    break
# Out:
# text 0 와 text 2 이 가장 유사합니다.

# %% [markdown]
# ### Image 생성 API

# %%
response = client.images.generate(
  prompt="A cute baby sea otter",
  n=2,
  size="1024x1024"
)

print(response)
# Out:
# ImagesResponse(created=1718593853, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vV0JFEecUSIx00tpFJyeNdmF/user-G2BphPbd4Y7h8zgKto1RrlhX/img-caT9UAb9M0lLvjthOONQb9mJ.png?st=2024-06-17T02%3A10%3A53Z&se=2024-06-17T04%3A10%3A53Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-16T12%3A06%3A40Z&ske=2024-06-17T12%3A06%3A40Z&sks=b&skv=2023-11-03&sig=HjqSWYjY9bFtIkdlP/YrwII2uqOArMJEGnmVRqk4d0o%3D'), Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vV0JFEecUSIx00tpFJyeNdmF/user-G2BphPbd4Y7h8zgKto1RrlhX/img-BBfGwn2SMpSsETRTk1caCbx9.png?st=2024-06-17T02%3A10%3A53Z&se=2024-06-17T04%3A10%3A53Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-06-16T12%3A06%3A40Z&ske=2024-06-17T12%3A06%3A40Z&sks=b&skv=2023-11-03&sig=YehgiELQkikiAHptf0mgq8yZvZotja9qpT8KAbHrYWQ%3D')])

# %% [markdown]
# # API Endpoint 이용
#
# payload"는 주로 HTTP 요청을 보낼 때 전달되는 데이터를 의미합니다. API 호출에서 "payload"는 주로 POST 요청의 본문에 포함된 데이터를 나타냅니다.
#
# - temperature : 사용할 샘플링 온도는 0에서 2 사이입니다. 0.8과 같이 값이 높을수록 출력이 더 무작위로 생성(Hallucination 발생 가능)되고, 0.2와 같이 값이 낮을수록 더 집중적이고 결정적이게 됩니다.
#
# - top_p : temperature의 대안으로, 확률 top_p인 토큰의 결과를 고려합니다. 따라서 0.1은 상위 10% 확률을 구성하는 토큰만 고려된다는 의미입니다.
#
# **temperature 와 top_p 중 하나만 변경하고, 둘 다 변경하지는 않는 것이 좋습니다.**
#
# - n:  각 입력 메시지에 대해 생성할 chat completion 선택 수입니다.
#
# -  presence_penalty : -2.0과 2.0 사이의 숫자입니다. 양수 값은 지금까지 텍스트에 나타나는지 여부에 따라 새 토큰에 불이익을 주어 모델이 새로운 주제에 관해 이야기할 가능성을 높입니다.
#
# - frequency_penalty : -2.0과 2.0 사이의 숫자입니다. 양수 값은 지금까지 텍스트의 기존 빈도를 기반으로 새 토큰에 불이익을 주어 모델이 동일한 줄을 그대로 반복할 가능성을 줄입니다.
#
# Bearer는 HTTP 인증 스키마 중 하나입니다. 웹 서비스에서 사용하는 토큰 기반의 인증 방식 중 가장 일반적인 방식입니다. Bearer를 사용하면, 클라이언트는 해당 토큰을 포함하여 서버에 요청을 보낼 수 있으며, 서버는 이 토큰을 검증하여 해당 클라이언트의 요청을 인증합니다. Bearer {토큰} 형식에서 {토큰} 부분은 실제 API를 사용하기 위한 인증 토큰을 나타냅니다.

# %%
import requests  

# 요청에 필요한 데이터를 payload 변수에 저장
payload = {
    "model": "gpt-3.5-turbo",  
    "messages": [{"role": "user", "content": f"세계 바둑 챔피언 이름은?"}],  
    "temperature": 1.0,  
    "top_p": 1.0,  
    "n": 1,  
    "stream": False,     # 스트림모드 사용 여부
    "presence_penalty": 0,  # 결과의 일관성에 영향
    "frequency_penalty": 0,  # 단어의 사용 빈도에 영향
}

# 요청 헤더에 내용 유형 및 인증 키 설정
headers = {
    "Content-Type": "application/json",  # 요청 본문의 유형을 JSON으로 지정
    "Authorization": f"Bearer {os.environ['OPENAI_API_KEY']}"  # 인증 키 포함
}

# requests.post를 사용하여 OpenAI API에 POST 요청을 보냅니다.
response = requests.post(URL, headers=headers, json=payload, stream=False)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### response 내용
# 1. **choices**: API 응답의 주요 내용이 포함된 배열입니다.
#    - **finish_reason**: 응답이 완료된 이유입니다. 'stop'은 출력이 종료된 이유가 됩니다.
#    - **index**: 선택 사항의 인덱스 번호입니다.
#    - **message**: 사용자 또는 보조프로그램의 메시지 내용입니다.
#      - **content**: 보조프로그램이 생성한 메시지 내용입니다.
#      - **role**: 이 메시지를 생성한 주체입니다.  'assistant'는 메시지가 OpenAI의 assistena program으로부터 생성되었다는 것을 의미합니다.
#
# 2. **created**: 응답이 생성된 시간의 타임스탬프입니다.
#
# 3. **id**: 응답에 할당된 고유 식별자입니다.
#
# 4. **model**: 사용된 모델의 이름입니다.
#
# 5. **object**: 이 객체의 유형을 나타냅니다. 'chat.completion'은 채팅 완료 응답임을 나타냅니다.
#
# 6. **usage**: 이 요청에서 사용된 토큰의 수를 나타내는 정보입니다.
#    - **completion_tokens**: 응답 내용에서 사용된 토큰 수입니다.
#    - **prompt_tokens**: 사용자의 원래 질문에서 사용된 토큰 수입니다.
#    - **total_tokens**: 전체 토큰 수입니다.

# %%
import pprint
import json

# 응답 내용을 JSON으로 파싱
response_json = response.json()

# 파싱된 JSON 내용을 pretty-print로 출력
pprint.pprint(response_json)
# Out:
# {'choices': [{'finish_reason': 'stop',
#               'index': 0,
#               'logprobs': None,
#               'message': {'content': "'이세돌'이라고 하는 한국의 프로 바둑 선수가 2021년에 세계 바둑 "
#                                      '챔피언으로 알려졌습니다.',
#                           'role': 'assistant'}}],
#  'created': 1721168062,
#  'id': 'chatcmpl-9lkj8ZPp2iOWHOeYvUu4FWC8bvi3T',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 57, 'prompt_tokens': 25, 'total_tokens': 82}}
