# %% [markdown]
# # API 사용 Overview

# %%
# !pip install -q openai
# !pip install -q python-dotenv

# %%
import os
import openai
import sys
sys.path.append('./')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ### OpenAI 사용 가능 모델 목록

# %%
counter = 0
for model in client.models.list():
    print(model.id)
# Out:
# dall-e-3
# whisper-1
# gpt-4-turbo-2024-04-09
# gpt-4-1106-preview
# dall-e-2
# gpt-4-turbo
# tts-1-hd-1106
# tts-1-hd
# gpt-4-turbo-preview
# tts-1
# tts-1-1106
# babbage-002
# gpt-4-0125-preview
# gpt-4o-2024-05-13
# text-embedding-3-small
# text-embedding-3-large
# gpt-3.5-turbo
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# text-embedding-ada-002
# gpt-3.5-turbo-16k
# davinci-002
# gpt-3.5-turbo-0125
# gpt-3.5-turbo-1106
# gpt-4-0613
# gpt-4o
# gpt-4

# %% [markdown]
# ### 채팅 API
#
# Chat Completions API : https://platform.openai.com/docs/guides/text-generation/chat-completions-api

# %% [markdown]
# ## role of the messages author
#
# OpenAI API에서 각 메시지의 저자(`author`) 역할은 다음과 같은 의미를 가집니다:
#
# 1. **system**: 시스템 관련 메시지나 지침. 예를 들면, 어시스턴트에게 특정 작업을 수행하는 방법에 대한 지침을 제공하는 경우에 사용됩니다. 이러한 지침은 어시스턴트의 응답을 안내하거나 제한할 수 있습니다.
#
# 2. **user**: 사용자가 입력한 메시지. 대체로 사용자의 질문, 요청, 지침 등을 나타냅니다.
#
# 3. **assistant**: 어시스턴트(즉, 모델)가 반환하는 응답 또는 메시지. 사용자의 질문에 대한 답변, 제안, 설명 등을 포함할 수 있습니다.

# %%
Model = "gpt-4o-mini-2024-07-18"

# %%
# Q & A
response = client.chat.completions.create(
  model=Model,
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "2022년 FIFA 월드컵 우승한 나라가 어디인가요?"},
    {"role": "assistant", "content": "2022년 FIFA 월드컵 우승국은 아르헨티나입니다."},
    {"role": "user", "content": "어디에서 개최되었나요?"}
  ]
)

response
# Out:
# ChatCompletion(id='chatcmpl-9nGadZr68A1aRx42t7JTj3DtE5Sd4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='2022년 FIFA 월드컵은 카타르에서 개최되었습니다. 이것은 중동에서 열린 최초의 월드컵이었습니다.', role='assistant', function_call=None, tool_calls=None))], created=1721528871, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_8b761cb050', usage=CompletionUsage(completion_tokens=29, prompt_tokens=68, total_tokens=97))

# %%
print(response.choices[0].message.content)
# Out:
# 2022년 FIFA 월드컵은 카타르에서 개최되었습니다. 이는 중동 지역에서 처음으로 열린 월드컵입니다.

# %%
# 시 작성
completion = client.chat.completions.create(
  model=Model,
  messages=[
    {"role": "system", "content": "You are a poetic assistant, 복잡한 프로그래밍 개념을 창의적인 방식으로 설명하는 데 능숙합니다."},
    {"role": "user", "content": "프로그래밍의 재귀 개념을 설명하는 시를 작성하세요."}
  ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='**재귀의 미로**\n\n숲속 깊은 곳에 길이 하나,  \n조용히 속삭이는 나무들 사이,  \n아무도 모르는 그 비밀의 문,  \n여기로 오면 다시 돌아와.\n\n어두운 지름길을 따라가면,  \n거울처럼 비친 자신의 모습,  \n“나는 누구인가?” 묻고 또 묻네,  \n미로의 끝은 또 다른 시작.\n\n내가 나를 부르는 목소리,  \n작고 귀여운 그토록 소중한,  \n기억의 궤적을 따라가면,  \n자꾸 되풀이하는 그 단어들.\n\n하나의 문제, 여러 갈래 길,  \n각각 스며드는 답을 찾고자,  \n나는 알아차려, 그 안의 힘,  \n바로 나 자신을 찾는 것.\n\n여기서 경이로운 내면을 보며,  \n프로그램이 태어난 연금술 같아,  \n부르면 돌아오는 그 사랑처럼,  \n재귀는 영원히 계속될 거야.\n\n끝은 없음, 시작도 없는,  \n우리가 걷는 이 소중한 여정,  \n반복되는 의리 속에 숨은,  \n지혜의 씨앗을 찾아내요.', role='assistant', function_call=None, tool_calls=None)

# %%
print(completion.choices[0].message.content)
# Out:
# **재귀의 미로**
#
# 숲속 깊은 곳에 길이 하나,
# 조용히 속삭이는 나무들 사이,
# 아무도 모르는 그 비밀의 문,
# 여기로 오면 다시 돌아와.
#
# 어두운 지름길을 따라가면,
# 거울처럼 비친 자신의 모습,
# “나는 누구인가?” 묻고 또 묻네,
# 미로의 끝은 또 다른 시작.
#
# 내가 나를 부르는 목소리,
# 작고 귀여운 그토록 소중한,
# 기억의 궤적을 따라가면,
# 자꾸 되풀이하는 그 단어들.
#
# 하나의 문제, 여러 갈래 길,
# 각각 스며드는 답을 찾고자,
# 나는 알아차려, 그 안의 힘,
# 바로 나 자신을 찾는 것.
#
# 여기서 경이로운 내면을 보며,
# 프로그램이 태어난 연금술 같아,
# 부르면 돌아오는 그 사랑처럼,
# 재귀는 영원히 계속될 거야.
#
# 끝은 없음, 시작도 없는,
# 우리가 걷는 이 소중한 여정,
# 반복되는 의리 속에 숨은,
# 지혜의 씨앗을 찾아내요.

# %%
# 블로그 생성
response = client.chat.completions.create(
  model=Model,
  messages=[
    {"role": "system", "content": "당신은 경험 많은 카피라이터입니다."},
    {"role": "user", "content": "스타크래프트에 대해 블로그를 생성해줘. "}
  ],
  max_tokens=700,
  temperature=1
)

print(response.choices[0].message.content)
# Out:
# 물론이죠! 스타크래프트에 관한 블로그 포스트를 작성해드릴게요. 아래는 블로그의 예시입니다.
#
# ---
#
# # 스타크래프트: 영원한 우주 전쟁의 서사
#
# ## 서론
# 스타크래프트(StarCraft)는 블리자드 엔터테인먼트가 개발한 실시간 전략(RTS) 게임으로, 1998년 처음 출시 이후 전 세계적으로 수많은 팬과 엄청난 인기를 얻었습니다. 이 블로그에서는 스타크래프트의 매력, 게임플레이, 그리고 커뮤니티에 대해 살펴보겠습니다.
#
# ## 1. 스타크래프트의 세계관
# 스타크래프트는 24세기 우주를 배경으로 하며, 인류와 외계 종족인 프로토스, 저그 간의 갈등을 중심으로 전개됩니다. 각 종족은 고유한 특성과 전략을 갖고 있어 플레이어는 자신의 스타일에 맞는 종족을 선택하여 전투를 벌일 수 있습니다.
#
# - **테란(Terran)**: 인류의 후예로, 기술과 전략에 의존하는 종족입니다. 유연한 플레이가 가능하여 초보자부터 전문가까지 모두에게 적합합니다.
#
# - **프로토스(Protoss)**: 고급 기술과 강력한 유닛을 보유한 외계 종족으로, 높은 방어력과 빠른 회복 속도를 자랑합니다. 그러나 자원 관리가 중요합니다.
#
# - **저그(Zerg)**: 수적으로 압도하는 전투 스타일과 빠른 생산 능력을 갖춘 생명체 종족입니다. 전투의 흐름을 조절하는 능력이 중요하며, 엄청난 군량을 동원해 상대를 압도합니다.
#
# ## 2. 게임플레이
# 스타크래프트의 기본적인 게임플레이는 자원 관리, 유닛 생산, 그리고 전투로 구성됩니다. 플레이어는 자신의 기지를 발전시키고 적의 기지를 파괴하기 위해 다양한 전략을 구사해야 합니다.
#
# - **자원 관리**: 게임 내에서 자원은 승리의 열쇠입니다. 충분한 자원을 확보하고 적절하게 분배하는 능력이 승패를 가르기도 합니다.
#
# - **전략적 선택**: 어떤 유닛을 조합할지, 언제 공격할지를 결정하는 것이 중요합니다. 각 종족의 특성에 따라 다양한 전략이 생겨납니다.
#
# - **멀티태스킹**: 한 번에 여러 가지 행동을 수행해야 하므로 효율적인 멀티태스킹이 필요합니다. 이는 고수들이 보여주는 놀라운 투skill 원인 중 하나입니다.
#
# ## 3. 커뮤니티와 e스포츠
# 스타크래프트는 단순한 게임이 아닌, 그 자체로 커다란 유산을 만들어냈습니다. e스포츠에서 스타크래프트는 상징적인 게임으로 자리 잡으며 전 세계 대회가 열렸습니다. 'GSL'(Global StarCraft II League)와 'IEM'(Intel Extreme Masters) 같은 대회는 프로게이머들의 기량을 보여주는 무대로, 팬층도 매우 두껍습니다.
#
# ## 4. 스타크래프트가 남

# %%
# 형식 지정
custom_content = """
스타크래프트에 대해 블로그를 생성해줘. 형식은 다음과 같이 작성해줘.

주제: 스타크래프트
주요 내용:
"""

response = client.chat.completions.create(
  model=Model,
  messages=[
    {"role": "system", "content": "당신은 경험 많은 카피라이터입니다."},
    {"role": "user", "content": custom_content}
  ],
  max_tokens=700,
  temperature=1
)

print(response.choices[0].message.content)
# Out:
# ## 스타크래프트: 전설의 전략 게임
#
# ### 주제: 스타크래프트
#
# 스타크래프트(StarCraft)는 1998년에 블리자드 엔터테인먼트에 의해 출시된 실시간 전략(RTS) 게임으로, 시간이 지나도 여전히 많은 팬들의 사랑을 받고 있는 게임입니다. 이 블로그 포스트에서는 스타크래프트의 역사, 게임 플레이, 경쟁 장면, 그리고 문화적 영향력에 대해 다뤄보겠습니다.
#
# ### 1. 스타크래프트의 역사
#
# 스타크래프트는 1998년 3월에 첫 번째 버전이 출시되었으며, 멀티플레이어와 단일 플레이어 모두를 지원하는 혁신적인 시스템을 도입했습니다. 게임은 가상의 우주를 배경으로 하여, 테란, 저그, 프로토스라는 세 종족이 자원을 관리하고, 군대를 조직하여 전투를 벌이는 내용으로 구성되어 있습니다. 게임은 그래픽과 스토리라인에서 높은 평가를 받으며, 출시 후 곧바로 전 세계적으로 큰 인기를 끌게 되었습니다.
#
# ### 2. 게임 플레이
#
# 스타크래프트의 재미는 바로 다양한 전략과 전술의 조합에서 비롯됩니다. 각 종족은 독특한 유닛과 건물을 가지고 있으며, 플레이어는 상황에 맞는 최적의 전략을 구사해야 합니다. 이 게임은 자원 관리, 기지 건설, 군사 전투가 핵심 요소로, 신속한 판단력과 뛰어난 손기술이 요구됩니다.
#
# - **테란**: 인류의 미래를 배경으로 한 종족으로, 이동과 방어의 균형 잡힌 유닛으로 유명합니다.
# - **저그**: 생명체의 진화와 군집의 힘을 강조하는 종족으로, 빠른 생산속도와 대규모 전투를 자랑합니다.
# - **프로토스**: 고급 기술과 방어력이 뛰어난 종족으로, 강력한 유닛을 보유하고 있지만 생산 비용이 높은 특징이 있습니다.
#
# ### 3. 경쟁 장면
#
# 스타크래프트는 단순한 오락을 넘어서 e스포츠의 거대한 기반이 되었습니다. 다양한 대회와 리그가 개최되었으며, 이는 많은 프로게이머들의 탄생으로 이어졌습니다. 한국에서는 특히 스타크래프트가 인기를 끌며, 많은 팬들이 생겼고, 유명한 프로게이머들이 탄생하였습니다. 예를 들면, '이영호', '임요환', '박정석' 등이 있습니다.
#
# ### 4. 문화적 영향력
#
# 스타크래프트는 단순한 게임을 넘어 문화적 현상이 되었습니다. 여러 대중 매체에서 스타크래프트의 캐릭터와 스토리가 등장하고 있으며, 덕질 문화, 팬 아트, 음악, 모드 등 다양한 콘텐츠가 생성되었습니다. 또한, 다양한 언어로 번역되어 전 세계의 플레이어들에게 접근 가능하게 되었습니다.
#
# ### 결론
#
# 스타크래프트는 20년 이상의 역사를 지니고 있으며, 여전히 많은 이들에게 사랑받고 있는 게임입니다. 끊임없는 전략, 치열한

# %% [markdown]
# ### Embedding API

# %%
Embedding_Model = "text-embedding-3-small"

# %%
response = client.embeddings.create(
  model=Embedding_Model,
  input="The food was delicious and the waiter..."
)

print(response)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.029828643426299095, 0.0008259337046183646, -0.08130206167697906, -0.06542624533176422, 0.035150397568941116, -0.034412506967782974, -0.011045989580452442, 0.04091935604810715, -0.03409946337342262, -0.05156285688281059, 0.01160499732941389, -0.02095160447061062, -0.0038627423346042633, -0.030275849625468254, 0.0229193102568388, 0.0034406916238367558, 0.011593816801905632, -0.013069597072899342, 0.001780439168214798, 0.03588828444480896, 0.024998819455504417, -0.0007239148253574967, -0.02430564910173416, 0.013896928168833256, -0.007826105691492558, 0.00331491488032043, -0.01996774971485138, 0.0014303606003522873, -0.012197544798254967, -0.018637312576174736, 0.025244781747460365, -0.006613059435039759, 0.02250564470887184, -0.01907333917915821, -0.049013782292604446, -0.026139194145798683, 0.05876287445425987, 0.004100320395082235, 0.024842295795679092, 0.011739159002900124, -0.02421620860695839, 0.06945110112428665, 0.05903119966387749, 0.015406249091029167, 0.04972931370139122, 0.006422996986657381, -0.04856657609343529, 0.02056029811501503, -0.00230311113409698, -0.033518094569444656, 0.014925502240657806, 0.01831308752298355, -0.0014534196816384792, 0.06126723065972328, -0.002368794521316886, 0.010078906081616879, 0.02681000344455242, 0.008977661840617657, 0.040539227426052094, -0.018659673631191254, 0.07007718831300735, 0.014981403015553951, -0.0018349423771724105, 0.00908387266099453, -0.01701619103550911, -0.03215411677956581, -0.03532927855849266, -0.0057465978898108006, 0.014098171144723892, -0.03624605014920235, 0.03324976935982704, 0.037252265959978104, -0.04700135812163353, -0.03752058744430542, 0.05585603788495064, -0.02649695985019207, -0.01112425047904253, -0.0586734339594841, -0.01751929707825184, -0.00935219693928957, -0.030141688883304596, -0.0032673992682248354, -0.01884973607957363, -0.0029627401381731033, 0.015014943666756153, -0.07522005587816238, -0.02247210405766964, 0.007009955123066902, 0.020236074924468994, 0.06220636144280434, -0.003968953620642424, -0.00303820613771677, 0.06547096371650696, -0.015819914638996124, 0.03926469013094902, -0.024126766249537468, -0.03206467255949974, 0.04065103083848953, -0.015115564689040184, 0.031237343326210976, 0.04548085480928421, -0.06193803995847702, 0.00921244453638792, -0.033428654074668884, 0.029918085783720016, -0.012286986224353313, 0.042350415140390396, -0.032869644463062286, -0.03664853796362877, -0.024663414806127548, 0.027525532990694046, -0.010732945054769516, -0.00687020318582654, -0.0012626583920791745, 0.018637312576174736, 0.02779385633766651, 0.033518094569444656, -0.07924491167068481, -0.017027370631694794, 0.004114295821636915, -0.00912859383970499, 0.028308143839240074, -0.05616908147931099, -0.044765327125787735, -0.033764056861400604, -0.06202748045325279, -0.03461374714970589, 0.016132958233356476, -0.022460924461483955, -0.02508825995028019, 0.057734303176403046, -0.006596289575099945, -0.01385220792144537, -0.02289695106446743, -0.006210573948919773, -0.001879662973806262, 0.00936896726489067, 0.013293200172483921, 0.0016672400524839759, -0.011359034106135368, -0.021622413769364357, 9.276031778426841e-05, 0.03119262307882309, -0.025356583297252655, -0.012633571401238441, -0.019822409376502037, -0.002909634495154023, 0.03485971316695213, -0.004712434019893408, 0.005209950730204582, -0.043915633112192154, -0.001134785357862711, -0.013393821194767952, -0.016054697334766388, -0.05746597796678543, 0.0014003139222040772, 0.028487026691436768, -0.02390316314995289, 0.0033708156552165747, 0.049684591591358185, -0.026250995695590973, 0.024171488359570503, -0.033540453761816025, 0.006143493112176657, -0.01227580662816763, 0.0458386205136776, -0.008234181441366673, 0.06193803995847702, -0.04440756142139435, -0.04281998053193092, 0.017250973731279373, 0.01679258793592453, 0.012577670626342297, 0.019308121874928474, -0.01374040637165308, -0.006115542724728584, 0.040293265134096146, -0.00616585370153188 ...

# %%
import numpy as np
embedding = np.array(response.data[0].embedding)
embedding.shape
# Out:
# (1536,)

# %% [markdown]
# - 여러개의 문장의 유사도 비교

# %%
from scipy.spatial.distance import cosine

# 텍스트 리스트
texts = [
     "음식이 맛있었고 웨이터가 매우 친절했습니다.",
     "분위기는 좋았지만 음식은 그냥 그래요.",
     "저는 음식이 마음에 들었고 웨이터는 매우 세심했습니다."
]

# 임베딩 생성 함수
def get_embedding(text):
    response = client.embeddings.create(
          model=Embedding_Model,
          input=text
        )
    return np.array(response.data[0].embedding)

# 임베딩 생성
embeddings = [get_embedding(text) for text in texts]

# 코사인 유사도 계산 함수
def cosine_similarity(vec1, vec2):
    return 1 - cosine(vec1, vec2)

# 코사인 유사도 계산 및 출력
simi_0_1 = cosine_similarity(embeddings[0], embeddings[1])
simi_0_2 = cosine_similarity(embeddings[0], embeddings[2])
simi_1_2 = cosine_similarity(embeddings[1], embeddings[2])

for i, text in enumerate(texts):
    print(f"test {i} : {text}")

print()
print(f"Similarity between text 0 and text 1: {simi_0_1}")
print(f"Similarity between text 0 and text 2: {simi_0_2}")
print(f"Similarity between text 1 and text 2: {simi_1_2}")
print()
# Out:
# test 0 : 음식이 맛있었고 웨이터가 매우 친절했습니다.
# test 1 : 분위기는 좋았지만 음식은 그냥 그래요.
# test 2 : 저는 음식이 마음에 들었고 웨이터는 매우 세심했습니다.
#
# Similarity between text 0 and text 1: 0.3771744641066792
# Similarity between text 0 and text 2: 0.7786700247930316
# Similarity between text 1 and text 2: 0.4185469381972111

# %%
# 각 유사도를 리스트로 정리
similarities = [
    (simi_0_1, (0, 1)),
    (simi_0_2, (0, 2)),
    (simi_1_2, (1, 2))
]

# 유사도를 내림차순으로 정렬하고 가장 유사한 쌍을 출력
for simi, pair in sorted(similarities, reverse=True):
    print(f"text {pair[0]} 와 text {pair[1]} 이 가장 유사합니다.")
    break
# Out:
# text 0 와 text 2 이 가장 유사합니다.

# %% [markdown]
# ### Image 생성 API

# %%
response = client.images.generate(
  prompt="A cute baby sea otter",
  n=2,
  size="512x512"
)

print(response)
# Out:
# ImagesResponse(created=1721529177, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vV0JFEecUSIx00tpFJyeNdmF/user-G2BphPbd4Y7h8zgKto1RrlhX/img-oeDlqSpGYO5FIIhWfSruSRgu.png?st=2024-07-21T01%3A32%3A57Z&se=2024-07-21T03%3A32%3A57Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-20T23%3A11%3A49Z&ske=2024-07-21T23%3A11%3A49Z&sks=b&skv=2023-11-03&sig=vSPqRZpWvt/ntxyGFNME5rPXa6dI0uh%2BzJkkE427MM8%3D'), Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-vV0JFEecUSIx00tpFJyeNdmF/user-G2BphPbd4Y7h8zgKto1RrlhX/img-iodyYjq0YesIolN6wWlSRDvj.png?st=2024-07-21T01%3A32%3A57Z&se=2024-07-21T03%3A32%3A57Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-20T23%3A11%3A49Z&ske=2024-07-21T23%3A11%3A49Z&sks=b&skv=2023-11-03&sig=Ols09jxgu0lPTzH64CJaSTYr2B3IltspGAbvnG4DWqc%3D')])

# %% [markdown]
# # API Endpoint 이용
#
# payload"는 주로 HTTP 요청을 보낼 때 전달되는 데이터를 의미합니다. API 호출에서 "payload"는 주로 POST 요청의 본문에 포함된 데이터를 나타냅니다.
#
# - temperature : 사용할 샘플링 온도는 0에서 2 사이입니다. 0.8과 같이 값이 높을수록 출력이 더 무작위로 생성(Hallucination 발생 가능)되고, 0.2와 같이 값이 낮을수록 더 집중적이고 결정적이게 됩니다.
#
# - top_p : temperature의 대안으로, 확률 top_p인 토큰의 결과를 고려합니다. 따라서 0.1은 상위 10% 확률을 구성하는 토큰만 고려된다는 의미입니다.
#
# **temperature 와 top_p 중 하나만 변경하고, 둘 다 변경하지는 않는 것이 좋습니다.**
#
# - n:  각 입력 메시지에 대해 생성할 chat completion 선택 수입니다.
#
# -  presence_penalty : -2.0과 2.0 사이의 숫자입니다. 양수 값은 지금까지 텍스트에 나타나는지 여부에 따라 새 토큰에 불이익을 주어 모델이 새로운 주제에 관해 이야기할 가능성을 높입니다.
#
# - frequency_penalty : -2.0과 2.0 사이의 숫자입니다. 양수 값은 지금까지 텍스트의 기존 빈도를 기반으로 새 토큰에 불이익을 주어 모델이 동일한 줄을 그대로 반복할 가능성을 줄입니다.
#
# Bearer는 HTTP 인증 스키마 중 하나입니다. 웹 서비스에서 사용하는 토큰 기반의 인증 방식 중 가장 일반적인 방식입니다. Bearer를 사용하면, 클라이언트는 해당 토큰을 포함하여 서버에 요청을 보낼 수 있으며, 서버는 이 토큰을 검증하여 해당 클라이언트의 요청을 인증합니다. Bearer {토큰} 형식에서 {토큰} 부분은 실제 API를 사용하기 위한 인증 토큰을 나타냅니다.

# %%
import requests  

# OpenAI API의 URL을 정의
URL = "https://api.openai.com/v1/chat/completions"

# 요청에 필요한 데이터를 payload 변수에 저장
payload = {
    "model": Model,  
    "messages": [{"role": "user", "content": f"세계 바둑 챔피언 이름은?"}],  
    "temperature": 1.0,  
    "top_p": 1.0,  
    "n": 1,  
    "stream": False,     # 스트림모드 사용 여부
    "presence_penalty": 0,  # 결과의 일관성에 영향
    "frequency_penalty": 0,  # 단어의 사용 빈도에 영향
}

# 요청 헤더에 내용 유형 및 인증 키 설정
headers = {
    "Content-Type": "application/json",  # 요청 본문의 유형을 JSON으로 지정
    "Authorization": f"Bearer {os.environ['OPENAI_API_KEY']}"  # 인증 키 포함
}

# requests.post를 사용하여 OpenAI API에 POST 요청을 보냅니다.
response = requests.post(URL, headers=headers, json=payload, stream=False)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### response 내용
# 1. **choices**: API 응답의 주요 내용이 포함된 배열입니다.
#    - **finish_reason**: 응답이 완료된 이유입니다. 'stop'은 출력이 종료된 이유가 됩니다.
#    - **index**: 선택 사항의 인덱스 번호입니다.
#    - **message**: 사용자 또는 보조프로그램의 메시지 내용입니다.
#      - **content**: 보조프로그램이 생성한 메시지 내용입니다.
#      - **role**: 이 메시지를 생성한 주체입니다.  'assistant'는 메시지가 OpenAI의 assistena program으로부터 생성되었다는 것을 의미합니다.
#
# 2. **created**: 응답이 생성된 시간의 타임스탬프입니다.
#
# 3. **id**: 응답에 할당된 고유 식별자입니다.
#
# 4. **model**: 사용된 모델의 이름입니다.
#
# 5. **object**: 이 객체의 유형을 나타냅니다. 'chat.completion'은 채팅 완료 응답임을 나타냅니다.
#
# 6. **usage**: 이 요청에서 사용된 토큰의 수를 나타내는 정보입니다.
#    - **completion_tokens**: 응답 내용에서 사용된 토큰 수입니다.
#    - **prompt_tokens**: 사용자의 원래 질문에서 사용된 토큰 수입니다.
#    - **total_tokens**: 전체 토큰 수입니다.

# %%
import pprint
import json

# 응답 내용을 JSON으로 파싱
response_json = response.json()

# 파싱된 JSON 내용을 pretty-print로 출력
pprint.pprint(response_json)
# Out:
# {'choices': [{'finish_reason': 'stop',
#               'index': 0,
#               'logprobs': None,
#               'message': {'content': '2023년 기준으로 세계 바둑 챔피언은 중국 선수인 '
#                                      '"커제(柯洁)"입니다. 그러나 바둑 대회는 정기적으로 열리기 때문에 최신 '
#                                      '정보를 확인하는 것이 중요합니다. 다른 질문이 있으시면 말씀해 주세요!',
#                           'role': 'assistant'}}],
#  'created': 1721529618,
#  'id': 'chatcmpl-9nGmgWwqlUBEvFaeEBHrUq0pl1JNA',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'system_fingerprint': 'fp_661538dc1f',
#  'usage': {'completion_tokens': 58, 'prompt_tokens': 18, 'total_tokens': 76}}
