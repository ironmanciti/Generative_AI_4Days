# %% [markdown]
# # Chat Models
# https://python.langchain.com/v0.2/docs/integrations/chat/

# %%
# !pip install -qU \
python-dotenv \
langchain \
langchain-community \
openai \
anthropic \
langchain-openai \
langchain-anthropic \
langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.2/164.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 9.7 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()
# Out:
# True

# %% [markdown]
# ## OpenAI Chat Model

# %%
#Model = "gpt-4o"
Model = "gpt-3.5-turbo"

# %%
model = ChatOpenAI(model=Model)

result =model.invoke("81을 9로 나누면 몇인가요?")
result
# Out:
# AIMessage(content='81을 9로 나누면 9가 됩니다.', response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 23, 'total_tokens': 39}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-76352e58-a791-4be9-8953-a7d9e2701b12-0', usage_metadata={'input_tokens': 23, 'output_tokens': 16, 'total_tokens': 39})

# %%
print(result.content)
# Out:
# 81을 9로 나누면 9가 됩니다.

# %% [markdown]
# ## Basic Conversation

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

messages = [
    SystemMessage(content="당신은  수학 문제를 잘 풀어주는 도움되는 assistant 입니다."),
    HumanMessage(content="81을 9로 나누면 몇인가요?")
]

result = model.invoke(messages)
print(result.content)
# Out:
# 81을 9로 나누면 9입니다.
#
# 이 문제를 풀이하는 과정은 다음과 같습니다:
#
# 1) 81 ÷ 9 = ?
#
# 2) 9 x 9 = 81이므로,
#
# 3) 81 ÷ 9 = 9
#
# 따라서 81을 9로 나눈 결과는 9입니다.
#
# 이 나눗셈에서는 나머지가 0이므로, 81은 9의 배수라고 할 수 있습니다.

# %%
messages = [
    SystemMessage(content="당신은  수학 문제를 잘 풀어주는 도움되는 assistant 입니다."),
    HumanMessage(content="81을 9로 나누면 몇인가요?"),
    AIMessage(content="81을 9로 나누면 9입니다."),
    HumanMessage(content="10 곱하기 5는 얼마인가요?")
]

result = model.invoke(messages)
print(result.content)
# Out:
# 10 곱하기 5는 50입니다.

# %% [markdown]
# ## Anthropic Chat Model

# %%
from langchain_anthropic import ChatAnthropic

model = ChatAnthropic(model="claude-3-5-sonnet-20240620")

result = model.invoke(messages)
print(result.content)
# Out:
# 81을 9로 나누는 계산을 해보겠습니다.
#
# 81 ÷ 9 = 9
#
# 계산 과정:
# 1. 81은 9의 배수입니다.
# 2. 9 x 9 = 81이므로, 81을 9로 나누면 9가 됩니다.
#
# 따라서, 81을 9로 나눈 결과는 9입니다.

# %% [markdown]
# ## Google Chat Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest")

result = model.invoke(messages)
print(result.content)
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised InternalServerError: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting.
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised InternalServerError: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting.
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised InternalServerError: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting.
# 10 곱하기 5는 50입니다.

# %% [markdown]
# ## Chat Model을 이용한 Conversation 구현

# %%
model = ChatOpenAI(model=Model)

chat_history = []

system_message = SystemMessage(content="You are a helpful AI assistant.")
chat_history.append(system_message)

while True:
    query = input("사용자: ")
    if query.lower() == "quit":
        break
    chat_history.append(HumanMessage(content=query))   # 사용자 message 추가

    result = model.invoke(chat_history)
    response = result.content
    chat_history.append(AIMessage(content=response))  # AI message 추가
    print(f"AI: {response}")

print("대화 History:")
print(chat_history)
# Out:
# 사용자: 한국에서 제일 높은 산이 어디야?
# AI: 한국에서 제일 높은 산은 한라산이에요. 한라산은 제주도에 위치해 있고, 해발 높이는 약 1950m 정도 되요. 등산을 즐기는 사람들에게 인기 있는 명소 중 하나이기도 해요.
# 사용자: 백두대간은 어디에서 시작해서 어디에서 끝나?
# AI: 백두대간은 한반도의 북쪽을 가로지르는 산맥으로, 한국의 북한과 중국을 연결하는 산맥이에요. 백두대간은 한국의 강원도에서 시작해서 경상북도를 거쳐 전북 지역까지 이어져요. 그리고 북한을 통과하여 중국으로 이어지게 되요. 이 산맥은 한반도의 북쪽 지역을 가로지르는 중요한 지형적 요소 중 하나이기도 해요.
# 사용자: QUIT
# 대화 History:
# [SystemMessage(content='You are a helpful AI assistant.'), HumanMessage(content='한국에서 제일 높은 산이 어디야?'), AIMessage(content='한국에서 제일 높은 산은 한라산이에요. 한라산은 제주도에 위치해 있고, 해발 높이는 약 1950m 정도 되요. 등산을 즐기는 사람들에게 인기 있는 명소 중 하나이기도 해요.'), HumanMessage(content='백두대간은 어디에서 시작해서 어디에서 끝나?'), AIMessage(content='백두대간은 한반도의 북쪽을 가로지르는 산맥으로, 한국의 북한과 중국을 연결하는 산맥이에요. 백두대간은 한국의 강원도에서 시작해서 경상북도를 거쳐 전북 지역까지 이어져요. 그리고 북한을 통과하여 중국으로 이어지게 되요. 이 산맥은 한반도의 북쪽 지역을 가로지르는 중요한 지형적 요소 중 하나이기도 해요.')]
