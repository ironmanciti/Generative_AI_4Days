# %% [markdown]
# ### Reasoning (추론)
#
# o3 및 o4-mini와 같은 추론 모델은 강화 학습을 통해 추론을 수행하도록 훈련된 LLM입니다. 추론 모델은 사용자에게 응답하기 전에 먼저 생각하여 , 사용자에게 응답하기 전에 긴 내부 사고 사슬을 생성합니다. 추론 모델은 복잡한 문제 해결, 코딩, 과학적 추론, 그리고 에이전트 워크플로우를 위한 다단계 계획 수립에 탁월합니다. 또한 , 경량 코딩 에이전트인 Codex CLI 에 가장 적합한 모델입니다.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
from openai import OpenAI
import json

client = OpenAI()

Model = "gpt-4.1-nano"

# %%
prompt = """
문자열로 표현된 행렬을 '[1,2],[3,4],[5,6]' 형식으로 받아서 같은 형식으로 전치행렬을 출력하는 파이썬 스크립트를 작성하세요.
"""

response = client.responses.create(
    model="o4-mini",
    reasoning={"effort": "medium"},
    input=[
        {
            "role": "user", 
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# 아래와 같은 파이썬 스크립트를 만들면, 입력된 문자열 `"[1,2],[3,4],[5,6]"` 을 파싱해서 전치행렬을 동일한 형식의 문자열로 출력할 수 있습니다.
#
# ```python
# import ast
#
# def parse_matrix(s):
#     # 전체를 리스트로 감싸서 ast.literal_eval 로 안전하게 파싱
#     return ast.literal_eval(f'[{s}]')
#
# def transpose(matrix):
#     # zip(*) 으로 전치
#     return [list(col) for col in zip(*matrix)]
#
# def format_matrix(matrix):
#     # [[…],[…],…] 형태를 "[…],[…],…" 문자열로 변환
#     return ','.join('[' + ','.join(map(str,row)) + ']' for row in matrix)
#
# def main():
#     s = input("행렬을 '[1,2],[3,4],[5,6]' 형식으로 입력하세요: ")
#     try:
#         mat = parse_matrix(s)
#     except Exception as e:
#         print("입력 형식 오류:", e)
#         return
#
#     t = transpose(mat)
#     out = format_matrix(t)
#     print("전치행렬:", out)
#
# if __name__ == "__main__":
#     main()
# ```
#
# 사용 예:
#  1. 실행 후
#     행렬을 '[1,2],[3,4],[5,6]' 형식으로 입력하세요: [1,2],[3,4],[5,6]
#  2. 출력
#     전치행렬: [1,3,5],[2,4,6]

# %%
import ast

def transpose_str_matrix(s: str) -> str:
    # 문자열 "[1,2],[3,4],[5,6]" → "[[1,2],[3,4],[5,6]]" 로 감싸서 literal_eval
    matrix = ast.literal_eval(f'[{s}]')
    # 전치
    transposed = list(map(list, zip(*matrix)))
    # "[[1,3,5],[2,4,6]]" → "[1,3,5],[2,4,6]"
    return ','.join('[' + ','.join(map(str, row)) + ']' for row in transposed)

s = "[1,2],[3,4],[5,6]"
print(transpose_str_matrix(s))
# Out:
# [1,3,5],[2,4,6]

# %% [markdown]
# ### Python 프로젝트 계획 및 생성

# %%
prompt = """
사용자 질문을 받아 답변과 매핑된 데이터베이스에서 검색하는 Python 앱을 만들고 싶습니다.
유사한 답변이 있으면 일치하는 답변을 검색합니다.
만약 일치하지 않으면 사용자에게 답변을 입력하도록 요청하고
질문/답변 쌍을 데이터베이스에 저장합니다. 필요한 디렉터리 구조를 계획한 후
각 파일을 전체적으로 반환합니다.
코드 전체가 아닌 시작과 끝에만 해설을 제공하세요.
"""

response = client.responses.create(
    model="o4-mini",
    input=[
        {
            "role": "user",
            "content": prompt,
        }
    ]
)

print(response.output_text)
# Out:
# 아래 예시는 Python CLI 앱으로, 사용자가 입력한 질문과 데이터베이스에 저장된 질문들 간의 유사도를 비교해 기존 답변을 찾아주거나(유사도 기준 θ=0.6), 새 답변을 입력받아 저장합니다.
#
# 디렉터리 구조 제안
# • qadb_app/
#  • main.py
#  • database/
#   • __init__.py
#   • db.py
#  • utils/
#   • __init__.py
#   • similarity.py
#  • requirements.txt
#
# 파일별 전체 코드
#
# 파일: qadb_app/main.py
# ```
# import sys
# from database import db
# from utils.similarity import find_best_match
#
# def main():
#     db.init_db()
#     print("질문/답변 시스템 (종료하려면 'exit' 입력)")
#     while True:
#         question = input("질문을 입력하세요: ").strip()
#         if question.lower() == 'exit':
#             print("종료합니다.")
#             sys.exit(0)
#         qas = db.get_all_qas()  # [(id, question, answer), ...]
#         candidates = [item[1] for item in qas]
#         best = find_best_match(question, candidates)
#         if best['score'] >= 0.6:
#             idx = best['index']
#             answer = qas[idx][2]
#             print("답변:", answer)
#         else:
#             answer = input("유사한 답변이 없습니다. 새 답변을 입력하세요: ").strip()
#             db.insert_qa(question, answer)
#             print("새 질문/답변이 저장되었습니다.\n")
#
# if __name__ == '__main__':
#     main()
# ```
#
# 파일: qadb_app/database/db.py
# ```
# import sqlite3
# import os
#
# DB_PATH = os.path.join(os.path.dirname(__file__), 'qadb.sqlite')
#
# def get_connection():
#     return sqlite3.connect(DB_PATH)
#
# def init_db():
#     conn = get_connection()
#     cur = conn.cursor()
#     cur.execute('''
#         CREATE TABLE IF NOT EXISTS qa (
#             id INTEGER PRIMARY KEY AUTOINCREMENT,
#             question TEXT NOT NULL,
#             answer TEXT NOT NULL
#         )
#     ''')
#     conn.commit()
#     conn.close()
#
# def get_all_qas():
#     conn = get_connection()
#     cur = conn.cursor()
#     cur.execute('SELECT id, question, answer FROM qa')
#     rows = cur.fetchall()
#     conn.close()
#     return rows
#
# def insert_qa(question, answer):
#     conn = get_connection()
#     cur = conn.cursor()
#     cur.execute('INSERT INTO qa (question, answer) VALUES (?, ?)', (question, answer))
#     conn.commit()
#     conn.close()
# ```
#
# 파일: qadb_app/utils/similarity.py
# ```
# from difflib import SequenceMatcher
#
# def similarity(a: str, b: str) -> float:
#     return SequenceMatcher(None, a, b).ratio()
#
# def find_best_match(query: str, candidates: list) -> dict:
#     best = {'index': None, 'score': 0.0, 'text': None}
#     for i, text in enumerate(candidates):
#         score = similarity(query, text)
#         if score > best['score']:
#             best = {'index': i, 'score': score, 'text': text}
#     return best
# ```
#
# 파일: qadb_app/requirements.txt
# ```
# # 표준 라이브러리만 사용하므로 빈 파일로 둬도 됩니다.
# ```
#
# 이로써 질문을 입력받아 유사도를 검사하고, 없으면 사용자에게 새 답변을 받아 저장하는 간단한 Python 앱이 완성되었습니다.

# %% [markdown]
# ## 추론 기반 코드 자동 생성 실습
#
# **"숫자로 이루어진 문자열이 주어질 때, 해당 숫자의 평균과 중앙값을 구하는 Python 함수를 작성하라."**
# 예를 들어 `"1, 5, 3, 8, 2"`라는 문자열이 입력되면 평균은 `3.8`, 중앙값은 `3`입니다.
#
#
# * `o4-mini` 추론 모델을 사용하여 위 문제를 해결하는 **Python 코드**를 생성하세요.
# * `reasoning={"effort": "medium"}` 또는 `reasoning={"effort": "high"}` 옵션을 사용하여 **모델의 내부 추론 과정**을 유도하세요.
# * 코드 실행 결과가 **정확한지 직접 검증**해보세요.
#
# ### 구현 조건
#
# * 문자열을 숫자 리스트로 변환하는 전처리 로직 포함
# * 평균(average)과 중앙값(median)을 계산하는 함수 구성
# * 코드 내에 주석 또는 단계별 설명이 포함되도록 모델에게 유도
# * 출력값 확인을 위한 예제 입력 포함 (`"1, 5, 3, 8, 2"`)
#
# * reasoning effort를 `low`, `medium`, `high`로 바꿔가며 결과물 비교
# * `json.loads()`로 실행 가능한 함수 형태로 모델이 응답하도록 유도해보기
